# %%
#import libaries
import numpy as np
import skimage 
from skimage import io
from skimage import color
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# load image
# eigener Algoritmus
Klassenzimmer_bi= io.imread(r'C:\Users\Jerome\Desktop\Code\Einführung\Klassenzimmer_bi.png')
Schulhaus_bi = io.imread(r'C:\Users\Jerome\Desktop\Code\Einführung\Schulhaus_bi.png')
TT_Platte_bi = io.imread(r'C:\Users\Jerome\Desktop\Code\Einführung\Tischtennisplatte_bi.png')

# %%
# Original
Klassenzimmer_og= io.imread(r'C:\Users\Jerome\Desktop\Code\Einführung\open source\Klassenzimmer OG.jpg')
Schulhaus_og = io.imread(r'C:\Users\Jerome\Desktop\Code\Einführung\open source\Schulhaus OG.jpeg')
TT_Platte_og = io.imread(r'C:\Users\Jerome\Desktop\Code\Einführung\open source\Tischtennisplatte OG.jpg')

# %%
#open source
#NN
Klassenzimmer_nn= io.imread(r'C:\Users\Jerome\Desktop\Code\Einführung\open source\Klassenzimmer NN.jpg')
Schulhaus_nn = io.imread(r'C:\Users\Jerome\Desktop\Code\Einführung\open source\Schulhaus NN.jpg')
TT_Platte_nn = io.imread(r'C:\Users\Jerome\Desktop\Code\Einführung\open source\Tischtennisplatte NN.jpg')

#BI
Klassenzimmer_BI = io.imread(r'C:\Users\Jerome\Desktop\Code\Einführung\open source\Klassenzimmer BI.jpg')
Schulhaus_BI = io.imread(r'C:\Users\Jerome\Desktop\Code\Einführung\open source\Schulhaus BI.jpg')
TT_Platte_BI = io.imread(r'C:\Users\Jerome\Desktop\Code\Einführung\open source\Tischtennisplatte BI.jpg')

# KI
Klassenzimmer_KI = io.imread(r'C:\Users\Jerome\Desktop\Code\Einführung\open source\Klassenzimmer KI.jpg')
Schulhaus_KI = io.imread(r'C:\Users\Jerome\Desktop\Code\Einführung\open source\Schulhaus KI.jpg')
TT_Platte_KI = io.imread(r'C:\Users\Jerome\Desktop\Code\Einführung\open source\Tischtennisplatte KI.jpg')

# %%
# OG zu eigene bi
print((np.sum(np.abs(Klassenzimmer_og - Klassenzimmer_bi)))/(1600 * 1200 *3))
print('_')
print(np.sum(np.abs(Schulhaus_og - Schulhaus_bi))/(1600 * 1200 *3))
print('_')
print(np.sum(np.abs(TT_Platte_og - TT_Platte_bi))/(1600 * 1200 *3))
# Out:
# 107.32585798611112
# _
# 115.13353402777778
# _
# 123.49043263888889

# %%
#eigener Algorithmus und OG (Klassenzimmer)
ergebnis = np.abs(Klassenzimmer_og - Klassenzimmer_bi)

# %%
plt.imshow(ergebnis, cmap = 'gray')
cbar = plt.colorbar()
cbar.ax.set_ylabel('255 - 0', rotation=270)
cbar.ax.get_yaxis().labelpad = 15

# %%
plt.imshow(ergebnis[:,:, 0], cmap = 'Reds' )
cbar = plt.colorbar()
cbar.ax.set_ylabel('255 - 0', rotation=270)
cbar.ax.get_yaxis().labelpad = 15

# %%
plt.imshow(ergebnis[:,:, 0])
cbar = plt.colorbar()
cbar.ax.set_ylabel('255 - 0', rotation=270)
cbar.ax.get_yaxis().labelpad = 15

# %%
plt.imshow(ergebnis[:,:, 1], cmap = 'Greens')
cbar = plt.colorbar()
cbar.ax.set_ylabel('255 - 0', rotation=270)
cbar.ax.get_yaxis().labelpad = 15

# %%
plt.imshow(ergebnis[:,:, 1])
cbar = plt.colorbar()
cbar.ax.set_ylabel('255 - 0', rotation=270)
cbar.ax.get_yaxis().labelpad = 15

# %%
plt.imshow(ergebnis[:,:, 2], cmap = 'Blues')
cbar = plt.colorbar()
cbar.ax.set_ylabel('255 - 0', rotation=270)
cbar.ax.get_yaxis().labelpad = 15

# %%
plt.imshow(ergebnis[:,:, 2])
cbar = plt.colorbar()
cbar.ax.set_ylabel('255 - 0', rotation=270)
cbar.ax.get_yaxis().labelpad = 15

# %%
#plt.hist(np.abs(ergebnis)[:,:, 0], bins = 8)

# %%
ergebnis_red = ergebnis[:,:, 0].flatten()
ergebnis_green = ergebnis[:,:,1].flatten()
ergebnis_blue = ergebnis[:,:,2].flatten()

# %%
sns.histplot(data = np.abs(ergebnis_red), binwidth = 16)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(data = np.abs(ergebnis_green), binwidth = 16)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(data = np.abs(ergebnis_blue), binwidth = 16)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
plt.hist(np.abs(ergebnis)[:,:, 1])
# Out:
# (array([[678.,   9.,   4., ...,   2.,   7., 500.],
#         [727.,   5.,   4., ...,   2.,   8., 454.],
#         [765.,   9.,   3., ...,   2.,  13., 408.],
#         ...,
#         [724.,   6.,   0., ...,   0.,   5., 465.],
#         [704.,   5.,   0., ...,   1.,   5., 485.],
#         [696.,   6.,   0., ...,   2.,   5., 491.]]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 1600 BarContainer objects>)

# %%
plt.hist(np.abs(ergebnis)[:,:, 2], bins = 8)
# Out:
# (array([[718.,   6.,   3., ...,   1.,   5., 467.],
#         [747.,   7.,   2., ...,   1.,   4., 439.],
#         [731.,   7.,   2., ...,   1.,   6., 453.],
#         ...,
#         [743.,   3.,   0., ...,   0.,   2., 452.],
#         [702.,   3.,   0., ...,   0.,   4., 491.],
#         [675.,   1.,   0., ...,   0.,   3., 521.]]),
#  array([  0.   ,  31.875,  63.75 ,  95.625, 127.5  , 159.375, 191.25 ,
#         223.125, 255.   ]),
#  <a list of 1600 BarContainer objects>)

# %%
plt.hist(np.concatenate((ergebnis[:,:, 0], ergebnis[:,:,1], ergebnis[:,:,2]),  axis = 1, ),bins = 8)
# Out:
# (array([[698.,   9.,   1., ...,   1.,   8., 483.],
#         [739.,   9.,   0., ...,   0.,   7., 445.],
#         [763.,   8.,   0., ...,   0.,  11., 418.],
#         ...,
#         [743.,   3.,   0., ...,   0.,   2., 452.],
#         [702.,   3.,   0., ...,   0.,   4., 491.],
#         [675.,   1.,   0., ...,   0.,   3., 521.]]),
#  array([  0.   ,  31.875,  63.75 ,  95.625, 127.5  , 159.375, 191.25 ,
#         223.125, 255.   ]),
#  <a list of 4800 BarContainer objects>)

# %%
plt.savefig('Histogramm.pdf')

# %%
sns.histplot(data = np.concatenate((ergebnis[:,:, 0], ergebnis[:,:,1], ergebnis[:,:,2]),  axis = 1, ), binwidth = 16)
# Out:
# <AxesSubplot:ylabel='Count'>
# C:\Users\Jerome\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_api\deprecation.py:412, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     402     deprecation_addendum = (
#     403         f"If any parameter follows {name!r}, they should be passed as "
#     404         f"keyword, not positionally.")
#     405     warn_deprecated(
#     406         since,
#     407         name=repr(name),
#    (...)
#     410                  else deprecation_addendum,
#     411         **kwargs)
# --> 412 return func(*inner_args, **inner_kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\backends\backend_agg.py:540, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     490 @_check_savefig_extra_args
#     491 @_api.delete_parameter("3.5", "args")
#     492 def print_png(self, filename_or_obj, *args,
#     493               metadata=None, pil_kwargs=None):
#     494     """
#     495     Write the figure to a PNG file.
#     496
#    (...)
#     538         *metadata*, including the default 'Software' key.
#     539     """
# --> 540     FigureCanvasAgg.draw(self)
#     541     mpl.image.imsave(
#     542         filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     543         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\backends\backend_agg.py:431, in FigureCanvasAgg.draw(self)
#     429 def draw(self):
#     430     # docstring inherited
# --> 431     self.renderer = self.get_renderer(cleared=True)
#     432     # Acquire a lock on the shared font cache.
#     433     with RendererAgg.lock, \
#     434          (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435           else nullcontext()):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\backends\backend_agg.py:447, in FigureCanvasAgg.get_renderer(self, cleared)
#     444 reuse_renderer = (hasattr(self, "renderer")
#     445                   and getattr(self, "_lastKey", None) == key)
#     446 if not reuse_renderer:
# --> 447     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     448     self._lastKey = key
#     449 elif cleared:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\backends\backend_agg.py:93, in RendererAgg.__init__(self, width, height, dpi)
#      91 self.width = width
#      92 self.height = height
# ---> 93 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      94 self._filter_renderers = []
#      96 self._update_methods()
#
# ValueError: Image size of 389x72039 pixels is too large. It must be less than 2^16 in each direction.

# %%
# OG zu NN
print(np.sum(np.abs(Klassenzimmer_og - Klassenzimmer_nn))/(1600 * 1200 *3))
print('_')
print(np.sum(np.abs(Schulhaus_og - Schulhaus_nn))/(1600 * 1200 *3))
print('_')
print(np.sum(np.abs(TT_Platte_og - TT_Platte_nn))/(1600 * 1200 *3))

# %%
# OG zu BI
print(np.sum(np.abs(Klassenzimmer_og - Klassenzimmer_BI)))
print('_')
print(np.sum(np.abs(Schulhaus_og - Schulhaus_BI)))
print('_')
print(np.sum(np.abs(TT_Platte_og - TT_Platte_BI)))

# %%
# OG zu KI
print(np.sum(np.abs(Klassenzimmer_og - Klassenzimmer_KI))/(1600 * 1200 *3))
print('_')
print(np.sum(np.abs(Schulhaus_og - Schulhaus_KI))/(1600 * 1200 *3))
print('_')
print(np.sum(np.abs(TT_Platte_og - TT_Platte_KI))/(1600 * 1200 *3))
